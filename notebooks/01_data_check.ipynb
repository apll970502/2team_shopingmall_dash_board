# %%
from pathlib import Path
import pandas as pd

# 1. 파일 경로 설정 (notebooks 폴더 기준 상위 경로의 data/raw 지정)
DATA_DIR = Path("../data/raw")

# 2. CSV 파일 4개 불러오기
customers = pd.read_csv(DATA_DIR / "customers.csv")
products = pd.read_csv(DATA_DIR / "products.csv")
orders = pd.read_csv(DATA_DIR / "orders.csv")
order_items = pd.read_csv(DATA_DIR / "order_items.csv")

# 3. 각 데이터의 크기(행, 열) 출력
print("고객 데이터 크기:", customers.shape)
print("상품 데이터 크기:", products.shape)
print("주문 데이터 크기:", orders.shape)
print("주문 상세 데이터 크기:", order_items.shape)

# 4. 고객 데이터 상위 5개 미리보기
customers.head()
# Out:
# 고객 데이터 크기: (1200, 6)
# 상품 데이터 크기: (300, 4)
# 주문 데이터 크기: (6000, 5)
# 주문 상세 데이터 크기: (14603, 5)
#    customer_id name gender  age city signup_date
# 0            1  오준수     남성   24   고양  2026-03-08
# 1            2  전서희     여성   27   고양  2025-03-09
# 2            3  권재윤     여성   45   서울  2024-08-12
# 3            4  송현진     여성   52   서울  2024-11-18
# 4            5  김준수     여성   64   서울  2024-06-24

# %%
# 각 데이터 프레임의 결측치(빈 값) 및 기본 정보 확인

print("=== 고객 데이터 정보 ===")
print(customers.info())
print("\n=== 주문 데이터 정보 ===")
print(orders.info())
# Out:
# === 고객 데이터 정보 ===
# <class 'pandas.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  1200 non-null   int64
#  1   name         1200 non-null   str
#  2   gender       1200 non-null   str
#  3   age          1200 non-null   int64
#  4   city         1200 non-null   str
#  5   signup_date  1200 non-null   datetime64[us]
# dtypes: datetime64[us](1), int64(2), str(3)
# memory usage: 81.0 KB
# None
#
# === 주문 데이터 정보 ===
# <class 'pandas.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        6000 non-null   int64
#  1   customer_id     6000 non-null   int64
#  2   order_date      6000 non-null   datetime64[us]
#  3   payment_method  6000 non-null   str
#  4   order_status    6000 non-null   str
# dtypes: datetime64[us](1), int64(2), str(2)
# memory usage: 372.3 KB
# None

# %%
print("=== 상품 데이터 정보 ===")
print(products.info())
print("\n=== 주문 상세 데이터 정보 ===")
print(order_items.info())
# Out:
# === 상품 데이터 정보 ===
# <class 'pandas.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_id    300 non-null    int64
#  1   product_name  300 non-null    str
#  2   category      300 non-null    str
#  3   price         300 non-null    int64
# dtypes: int64(2), str(2)
# memory usage: 22.8 KB
# None
#
# === 주문 상세 데이터 정보 ===
# <class 'pandas.DataFrame'>
# RangeIndex: 14603 entries, 0 to 14602
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_item_id  14603 non-null  int64
#  1   order_id       14603 non-null  int64
#  2   product_id     14603 non-null  int64
#  3   quantity       14603 non-null  int64
#  4   unit_price     14603 non-null  int64
# dtypes: int64(5)
# memory usage: 570.6 KB
# None

# %%
# 1. 날짜 컬럼을 datetime 타입으로 변환
customers['signup_date'] = pd.to_datetime(customers['signup_date'])
orders['order_date'] = pd.to_datetime(orders['order_date'])

# 2. 수치형 데이터 기초 통계 확인 (연령, 가격, 수량 등)
print("=== 고객 연령 통계 ===")
print(customers['age'].describe())

print("\n=== 상품 가격 통계 ===")
print(products['price'].describe())

print("\n=== 주문 수량 및 단가 통계 ===")
print(order_items[['quantity', 'unit_price']].describe())
# Out:
# === 고객 연령 통계 ===
# count    1200.000000
# mean       36.408333
# std        10.607247
# min        18.000000
# 25%        29.000000
# 50%        36.000000
# 75%        43.000000
# max        69.000000
# Name: age, dtype: float64
#
# === 상품 가격 통계 ===
# count       300.000000
# mean      82423.333333
# std       70271.742887
# min        4000.000000
# 25%       30750.000000
# 50%       62500.000000
# 75%      115000.000000
# max      371000.000000
# Name: price, dtype: float64
#
# === 주문 수량 및 단가 통계 ===
#            quantity     unit_price
# count  14603.000000   14603.000000
# mean       1.615832   77884.400466
# std        0.948504   65289.672212
# min        1.000000    3200.000000
# 25%        1.000000   29700.000000
# 50%        1.000000   59000.000000
# 75%        2.000000  107000.000000
# max        5.000000  371000.000000

# %%
# 기본키(ID) 중복 확인 & 결측치 개수 최종 점검
print("=== 중복 확인 (False면 정상) ===")
print("고객 ID 중복:", customers['customer_id'].duplicated().any())
print("상품 ID 중복:", products['product_id'].duplicated().any())
print("주문 ID 중복:", orders['order_id'].duplicated().any())

print("\n=== 결측치 최종 점검 ===")
print("고객 결측치 수:", customers.isnull().sum().sum())
print("상품 결측치 수:", products.isnull().sum().sum())
print("주문 결측치 수:", orders.isnull().sum().sum())
print("주문상세 결측치 수:", order_items.isnull().sum().sum())
# Out:
# === 중복 확인 (False면 정상) ===
# 고객 ID 중복: False
# 상품 ID 중복: False
# 주문 ID 중복: False
#
# === 결측치 최종 점검 ===
# 고객 결측치 수: 0
# 상품 결측치 수: 0
# 주문 결측치 수: 0
# 주문상세 결측치 수: 0
